# %% [markdown]
# [<img width="200" alt="get in touch with Consensys Diligence" src="https://user-images.githubusercontent.com/2865694/56826101-91dcf380-685b-11e9-937c-af49c2510aa0.png">](https://diligence.consensys.net)<br/>
# <sup>
# [[  🌐  ](https://diligence.consensys.net)  [  📩  ](https://github.com/ConsenSys/vscode-solidity-doppelganger/blob/master/mailto:diligence@consensys.net)  [  🔥  ](https://consensys.github.io/diligence/)]
# </sup><br/><br/>
#
#
# # Hallucinate.sol - from pre-trained model

# %% [markdown]
# ## Setup
#
# We need to make our `soliditygen` module available to google collab. There's two ways to do this:
#
# * (a) via google drive
#   1. copy the files from https://github.com/tintinweb/hallucinate.sol to your personal google drive into `/MyDrive/collab/solidity-gen`
#   2. run the next two steps and provide your authenticator token
# * (b) by downloading the repo

# %%
# %tensorflow_version 2.x

# %%
import os
"""
# (1) mount the google drive in order for the code to find the soliditygen module

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
os.chdir('/content/drive/MyDrive/collab/solidity-gen')

"""
# (2) checkout the repo instead

# !git clone https://github.com/tintinweb/hallucinate.sol.git
os.chdir("hallucinate.sol")


# !ls -lsat .
### import everything because we're lazy
from soliditygen import *
# Out:
# Cloning into 'hallucinate.sol'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 55 (delta 24), reused 27 (delta 8), pack-reused 0
# Unpacking objects: 100% (55/55), done.
# total 112
#  4 drwxr-xr-x 4 root root  4096 Nov 12 12:09 .
#  4 drwxr-xr-x 8 root root  4096 Nov 12 12:09 .git
# 60 -rw-r--r-- 1 root root 57752 Nov 12 12:09 tutorial_1_train_and_hallucinate_save_restore_continue_training.ipynb
# 12 -rw-r--r-- 1 root root  9837 Nov 12 12:09 tutorial_2_hallucinate_from_pretrained_model.ipynb
# 12 -rw-r--r-- 1 root root  8299 Nov 12 12:09 soliditygen.py
#  4 drwxr-xr-x 3 root root  4096 Nov 12 12:09 solidity_model_text
#  4 -rw-r--r-- 1 root root  1610 Nov 12 12:09 .gitignore
#  8 -rw-r--r-- 1 root root  4736 Nov 12 12:09 README.md
#  4 drwxr-xr-x 1 root root  4096 Nov 12 12:09 ..

# %% [markdown]
# ## Load an existing model
#
# Restore the saved state from local folder `solidity_model`, then, hallucinate more solidity code 🙌

# %%
### creat dummy trainingData object and load existing state from the local dir
trainingData = TrainingData()
trainingData.load_model("solidity_model_text") # location of model

# %% [markdown]
# ## Predict
#
# Hallucinate more solidity 🙌

# %%
start = time.time()

# ------> hallucination go brrrrr: start from "contract ", generate 3000 chars
textOut = trainingData.predict(['contract '], 3000)
# <-----

end = time.time()
print(textOut, '\n\n' + '_'*80)
print('\nRun time:', end - start)
# Out:
# contract Decleawnen  {
#     struct Revy { return started;
#     }
#     function mint(address _to, uint _value) onlyBanker hasSupply
#         balances[tokenOwner] = tokenDistrust.balanceOf(this);
#         token.transfer(owner, tokensDistributionBatch);
#     }
#     function extraData
#         external onlyOwnerOfChamp(team2Token )
#         {
#             tokenSaleContract.owner(fashionIdToApproved[_tokenId];
#             require(_payFees < (32 != 0x00);
#             _FromFight(to, j+i);
#             if ((internalCheck()) {
#                 indexed += 150;
#             bountySum = founders[founderAddress];
#                 }
#                 else {
#                 emit1.endingBuy(0x0, msg.sender, msg.value, tokenAmount, getHyid(fashionAttor[msg.sender]), developerReserved);
#             }
#         }
#         rw.generToken(msg.sender, msg.value);
#         Upgrade(msg.sender, userAddress, value);
#         participants[participant].processedDividends += remainingTokens - lopeeDeptr * publicKey.freezings[msg.sender];
#         balances[msg.sender] = tokens;
#         saleTimeStatus = false;
#         saleOrderList[saleId].sender = saleId;
#         _transfer(administrators[keccyAddress], orchasEnisTime);
#         assets[msg.sender].Withdrawn
#     {
#         len = referrals[msg.sender].paymentEther;
#     }
#     function getDiffiluesForI(uint256 existing) external view returns(bool isReserved){
#         balances[beneficiary] = balances[userToAmbarableInternalAddress].add(tokens);
#         emit Transfer(msg.sender, to, value);
#     }
#     function exist(address addr)
#         external
#         payable
#     {
#         if (msg.value > 1) || (coinAgeRecord(owner, amount));
#         emit TokensUllocked(startQuater);
#     }
#     function deploy(eth depIssued + 5 forcurrentBalance msg.value, conditionFinCress);
#         contributeTokens(reservedAddress);
#         owners.spenderOrAddress(msg.sender, total);
#         emit Transfer(msg.sender, toAddress, tokens);
#         emit TokenReward(participants[lastIndex];
#         uint256 deposit = deposits[msg.sender];
#         uint64 money = ethInvestedAmountE8;
#         uint64 cashDealAmountE8 = uint64(keccak256(newCash)) % 60);
#     }
#     function getWeeked()
#         public
#         view
#         returns (uint transactionId)
#     {
#         this,
#         _stats.totalWageredGwei + _payFees += _amount;
#         if (currentuteOtedVestings == candidateExcess).length || size = _tranches / 1 days);
#         _;
#     }
#     keccak256(registrant)
#         onlyCofder    ;
#     }
#     function showNumberstERagIndividApproved(address userAddress)
#         exchangeValues[dataCanceOffset] += eate;
#         whitelistedParticipants.push(addr);
#         StocBalance.mul(50000, feeEtherBonus);
#     }
#     function setXPAAssets(
#         address _classReceiver,
#         uint256 _tokenId2,
#         uint256 _oneTokenInEur,
#         uint256 _actualFees,
#         uint256 _tokenId2,
#         uint256 _ownerTokenGind
#         unitsTokens_ - _tokenVesting,
#         uint256 _oneBack,
#         uint256 tokens,
#         uint
#
# ________________________________________________________________________________
#
# Run time: 16.82699179649353
